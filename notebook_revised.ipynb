# %% [markdown]
# # Proyek Analisis Data: Bike Sharing
# - **Nama:** Duevano Fairuz Pandya
# - **Email:** duevanofairuz@gmail.com
# - **ID Dicoding:** duevanofairuz

# %% [markdown]
# ## Menentukan Pertanyaan Bisnis

# %% [markdown]
# - Pertanyaan 1: Bagaimana pengaruh temperatur udara terhadap penggunaan sepeda?
# - Pertanyaan 2: Bagaimana perkembangan casual dan registered user selama 2 tahun ini?
# - Pertanyaan 3: Bagaimana perbedaan penggunaan sepeda di tiap harinya untuk setiap tahun? (Hari apa yang paling laris?)

# %% [markdown]
# ## Import Semua Packages/Library yang Digunakan

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import calendar
import warnings
from babel.numbers import format_currency
sns.set(style='dark')

# %% [markdown]
# ## Data Wrangling

# %% [markdown]
# ### Gathering Data

# %% [markdown]
# #### A. Gathering data dari hour.csv

# %%
#hour_df
hour_df = pd.read_csv('./data/hour.csv')
hour_df.head()
# Out:
#    instant      dteday  season  yr  mnth  hr  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1   0        0        6           0
# 1        2  2011-01-01       1   0     1   1        0        6           0
# 2        3  2011-01-01       1   0     1   2        0        6           0
# 3        4  2011-01-01       1   0     1   3        0        6           0
# 4        5  2011-01-01       1   0     1   4        0        6           0
#
#    weathersit  temp   atemp   hum  windspeed  casual  registered  cnt
# 0           1  0.24  0.2879  0.81        0.0       3          13   16
# 1           1  0.22  0.2727  0.80        0.0       8          32   40
# 2           1  0.22  0.2727  0.80        0.0       5          27   32
# 3           1  0.24  0.2879  0.75        0.0       3          10   13
# 4           1  0.24  0.2879  0.75        0.0       0           1    1

# %% [markdown]
# #### B. Gathering data dari day.csv

# %%
#day_df
day_df = pd.read_csv('./data/day.csv')
day_df.head()
# Out:
#    instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1        0        6           0
# 1        2  2011-01-02       1   0     1        0        0           0
# 2        3  2011-01-03       1   0     1        0        1           1
# 3        4  2011-01-04       1   0     1        0        2           1
# 4        5  2011-01-05       1   0     1        0        3           1
#
#    weathersit      temp     atemp       hum  windspeed  casual  registered  \
# 0           2  0.344167  0.363625  0.805833   0.160446     331         654
# 1           2  0.363478  0.353739  0.696087   0.248539     131         670
# 2           1  0.196364  0.189405  0.437273   0.248309     120        1229
# 3           1  0.200000  0.212122  0.590435   0.160296     108        1454
# 4           1  0.226957  0.229270  0.436957   0.186900      82        1518
#
#     cnt
# 0   985
# 1   801
# 2  1349
# 3  1562
# 4  1600

# %% [markdown]
# ### Assessing Data

# %% [markdown]
# #### A. Assessing hour_df

# %%
# mengecek isi entry data untuk setiap kolomnya di hour_df
hour_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17379 entries, 0 to 17378
# Data columns (total 17 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     17379 non-null  int64
#  1   dteday      17379 non-null  object
#  2   season      17379 non-null  int64
#  3   yr          17379 non-null  int64
#  4   mnth        17379 non-null  int64
#  5   hr          17379 non-null  int64
#  6   holiday     17379 non-null  int64
#  7   weekday     17379 non-null  int64
#  8   workingday  17379 non-null  int64
#  9   weathersit  17379 non-null  int64
#  10  temp        17379 non-null  float64
#  11  atemp       17379 non-null  float64
#  12  hum         17379 non-null  float64
#  13  windspeed   17379 non-null  float64
#  14  casual      17379 non-null  int64
#  15  registered  17379 non-null  int64
#  16  cnt         17379 non-null  int64
# dtypes: float64(4), int64(12), object(1)
# memory usage: 2.3+ MB

# %%
#cek missing value dari hour_df
hour_df.isna().sum()
# Out:
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# hr            0
# holiday       0
# weekday       0
# workingday    0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64

# %%
#cek duplikasi data di hour_df
print("Jumlah record hour_df yang terduplikasi: ", hour_df.duplicated().sum())
# Out:
# Jumlah record hour_df yang terduplikasi:  0

# %%
#mengecek descriptive statistics dari hour_df
hour_df.describe()
# Out:
#           instant        season            yr          mnth            hr  \
# count  17379.0000  17379.000000  17379.000000  17379.000000  17379.000000
# mean    8690.0000      2.501640      0.502561      6.537775     11.546752
# std     5017.0295      1.106918      0.500008      3.438776      6.914405
# min        1.0000      1.000000      0.000000      1.000000      0.000000
# 25%     4345.5000      2.000000      0.000000      4.000000      6.000000
# 50%     8690.0000      3.000000      1.000000      7.000000     12.000000
# 75%    13034.5000      3.000000      1.000000     10.000000     18.000000
# max    17379.0000      4.000000      1.000000     12.000000     23.000000
#
#             holiday       weekday    workingday    weathersit          temp  \
# count  17379.000000  17379.000000  17379.000000  17379.000000  17379.000000
# mean       0.028770      3.003683      0.682721      1.425283      0.496987
# std        0.167165      2.005771      0.465431      0.639357      0.192556
# min        0.000000      0.000000      0.000000      1.000000      0.020000
# 25%        0.000000      1.000000      0.000000      1.000000      0.340000
# 50%        0.000000      3.000000      1.000000      1.000000      0.500000
# 75%        0.000000      5.000000      1.000000      2.000000      0.660000
# max        1.000000      6.000000      1.000000      4.000000      1.000000
#
#               atemp           hum     windspeed        casual    registered  \
# count  17379.000000  17379.000000  17379.000000  17379.000000  17379.000000
# mean       0.475775      0.627229      0.190098     35.676218    153.786869
# std        0.171850      0.192930      0.122340     49.305030    151.357286
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.333300      0.480000      0.104500      4.000000     34.000000
# 50%        0.484800      0.630000      0.194000     17.000000    115.000000
# 75%        0.621200      0.780000      0.253700     48.000000    220.000000
# max        1.000000      1.000000      0.850700    367.000000    886.000000
#
#                 cnt
# count  17379.000000
# mean     189.463088
# std      181.387599
# min        1.000000
# 25%       40.000000
# 50%      142.000000
# 75%      281.000000
# max      977.000000

# %% [markdown]
# Yang perlu di cleaning dari hour_df:
# - Format date masih bertipe object padahal seharusnya bertipe datetime
# - kolom season, yr, dan weekday dapat diganti menjadi string untuk keperluan visualisasi

# %% [markdown]
# #### B. Assessing day_df

# %%
# mengecek isi entry data untuk setiap kolomnya
day_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 731 entries, 0 to 730
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     731 non-null    int64
#  1   dteday      731 non-null    object
#  2   season      731 non-null    int64
#  3   yr          731 non-null    int64
#  4   mnth        731 non-null    int64
#  5   holiday     731 non-null    int64
#  6   weekday     731 non-null    int64
#  7   workingday  731 non-null    int64
#  8   weathersit  731 non-null    int64
#  9   temp        731 non-null    float64
#  10  atemp       731 non-null    float64
#  11  hum         731 non-null    float64
#  12  windspeed   731 non-null    float64
#  13  casual      731 non-null    int64
#  14  registered  731 non-null    int64
#  15  cnt         731 non-null    int64
# dtypes: float64(4), int64(11), object(1)
# memory usage: 91.5+ KB

# %%
#cek missing value dari day_df
day_df.isna().sum()
# Out:
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# holiday       0
# weekday       0
# workingday    0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64

# %%
#cek duplikasi data dari day_df
print("Jumlah record day_df yang terduplikasi: ", day_df.duplicated().sum())
# Out:
# Jumlah record day_df yang terduplikasi:  0

# %%
#mengecek descriptive statistics dari day_df
day_df.describe()
# Out:
#           instant      season          yr        mnth     holiday     weekday  \
# count  731.000000  731.000000  731.000000  731.000000  731.000000  731.000000
# mean   366.000000    2.496580    0.500684    6.519836    0.028728    2.997264
# std    211.165812    1.110807    0.500342    3.451913    0.167155    2.004787
# min      1.000000    1.000000    0.000000    1.000000    0.000000    0.000000
# 25%    183.500000    2.000000    0.000000    4.000000    0.000000    1.000000
# 50%    366.000000    3.000000    1.000000    7.000000    0.000000    3.000000
# 75%    548.500000    3.000000    1.000000   10.000000    0.000000    5.000000
# max    731.000000    4.000000    1.000000   12.000000    1.000000    6.000000
#
#        workingday  weathersit        temp       atemp         hum   windspeed  \
# count  731.000000  731.000000  731.000000  731.000000  731.000000  731.000000
# mean     0.683995    1.395349    0.495385    0.474354    0.627894    0.190486
# std      0.465233    0.544894    0.183051    0.162961    0.142429    0.077498
# min      0.000000    1.000000    0.059130    0.079070    0.000000    0.022392
# 25%      0.000000    1.000000    0.337083    0.337842    0.520000    0.134950
# 50%      1.000000    1.000000    0.498333    0.486733    0.626667    0.180975
# 75%      1.000000    2.000000    0.655417    0.608602    0.730209    0.233214
# max      1.000000    3.000000    0.861667    0.840896    0.972500    0.507463
#
#             casual   registered          cnt
# count   731.000000   731.000000   731.000000
# mean    848.176471  3656.172367  4504.348837
# std     686.622488  1560.256377  1937.211452
# min       2.000000    20.000000    22.000000
# 25%     315.500000  2497.000000  3152.000000
# 50%     713.000000  3662.000000  4548.000000
# 75%    1096.000000  4776.500000  5956.000000
# max    3410.000000  6946.000000  8714.000000

# %%
#mengecek apakah weathersit memang tidak ada yang berindeks 4 (Hujan deras + Es + Badai petir + Kabut, Salju + Kabut)
print(day_df[day_df.weathersit == 4])
# Out:
# Empty DataFrame
# Columns: [instant, dteday, season, yr, mnth, holiday, weekday, workingday, weathersit, temp, atemp, hum, windspeed, casual, registered, cnt]
# Index: []

# %% [markdown]
# Yang perlu di cleaning dari day_df:
# - Format date masih bertipe object padahal seharusnya bertipe datetime
# - kolom season, yr, dan weekday dapat diganti menjadi string untuk keperluan visualisasi

# %% [markdown]
# ### Cleaning Data

# %% [markdown]
# #### A. Cleaning hour_df (mengubah tipe data dteday menjadi datetime)

# %%
datetime_columns = ["dteday"]

#iterasi untuk mengubah format data
for column in datetime_columns:
  hour_df[column] = pd.to_datetime(hour_df[column])

#pengecekan kembali
hour_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17379 entries, 0 to 17378
# Data columns (total 17 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     17379 non-null  int64
#  1   dteday      17379 non-null  datetime64[ns]
#  2   season      17379 non-null  int64
#  3   yr          17379 non-null  int64
#  4   mnth        17379 non-null  int64
#  5   hr          17379 non-null  int64
#  6   holiday     17379 non-null  int64
#  7   weekday     17379 non-null  int64
#  8   workingday  17379 non-null  int64
#  9   weathersit  17379 non-null  int64
#  10  temp        17379 non-null  float64
#  11  atemp       17379 non-null  float64
#  12  hum         17379 non-null  float64
#  13  windspeed   17379 non-null  float64
#  14  casual      17379 non-null  int64
#  15  registered  17379 non-null  int64
#  16  cnt         17379 non-null  int64
# dtypes: datetime64[ns](1), float64(4), int64(12)
# memory usage: 2.3 MB

# %% [markdown]
# #### B. Cleaning day_df (mengubah tipe data dteday menjadi datetime)

# %%
datetime_columns = ["dteday"]

for column in datetime_columns:
  day_df[column] = pd.to_datetime(day_df[column])

day_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 731 entries, 0 to 730
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     731 non-null    int64
#  1   dteday      731 non-null    datetime64[ns]
#  2   season      731 non-null    int64
#  3   yr          731 non-null    int64
#  4   mnth        731 non-null    int64
#  5   holiday     731 non-null    int64
#  6   weekday     731 non-null    int64
#  7   workingday  731 non-null    int64
#  8   weathersit  731 non-null    int64
#  9   temp        731 non-null    float64
#  10  atemp       731 non-null    float64
#  11  hum         731 non-null    float64
#  12  windspeed   731 non-null    float64
#  13  casual      731 non-null    int64
#  14  registered  731 non-null    int64
#  15  cnt         731 non-null    int64
# dtypes: datetime64[ns](1), float64(4), int64(11)
# memory usage: 91.5 KB

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %% [markdown]
# ### A. Explore hour_df

# %%
#melihat semua kolom menggunakan include all
hour_df.describe(include="all")
# Out:
# <ipython-input-20-89185787571c>:2: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   hour_df.describe(include="all")
#            instant               dteday        season            yr  \
# count   17379.0000                17379  17379.000000  17379.000000
# unique         NaN                  731           NaN           NaN
# top            NaN  2011-01-01 00:00:00           NaN           NaN
# freq           NaN                   24           NaN           NaN
# first          NaN  2011-01-01 00:00:00           NaN           NaN
# last           NaN  2012-12-31 00:00:00           NaN           NaN
# mean     8690.0000                  NaN      2.501640      0.502561
# std      5017.0295                  NaN      1.106918      0.500008
# min         1.0000                  NaN      1.000000      0.000000
# 25%      4345.5000                  NaN      2.000000      0.000000
# 50%      8690.0000                  NaN      3.000000      1.000000
# 75%     13034.5000                  NaN      3.000000      1.000000
# max     17379.0000                  NaN      4.000000      1.000000
#
#                 mnth            hr       holiday       weekday    workingday  \
# count   17379.000000  17379.000000  17379.000000  17379.000000  17379.000000
# unique           NaN           NaN           NaN           NaN           NaN
# top              NaN           NaN           NaN           NaN           NaN
# freq             NaN           NaN           NaN           NaN           NaN
# first            NaN           NaN           NaN           NaN           NaN
# last             NaN           NaN           NaN           NaN           NaN
# mean        6.537775     11.546752      0.028770      3.003683      0.682721
# std         3.438776      6.914405      0.167165      2.005771      0.465431
# min         1.000000      0.000000      0.000000      0.000000      0.000000
# 25%         4.000000      6.000000      0.000000      1.000000      0.000000
# 50%         7.000000     12.000000      0.000000      3.000000      1.000000
# 75%        10.000000     18.000000      0.000000      5.000000      1.000000
# max        12.000000     23.000000      1.000000      6.000000      1.000000
#
#           weathersit          temp         atemp           hum     windspeed  \
# count   17379.000000  17379.000000  17379.000000  17379.000000  17379.000000
# unique           NaN           NaN           NaN           NaN           NaN
# top              NaN           NaN           NaN           NaN           NaN
# freq             NaN           NaN           NaN           NaN           NaN
# first            NaN           NaN           NaN           NaN           NaN
# last             NaN           NaN           NaN           NaN           NaN
# mean        1.425283      0.496987      0.475775      0.627229      0.190098
# std         0.639357      0.192556      0.171850      0.192930      0.122340
# min         1.000000      0.020000      0.000000      0.000000      0.000000
# 25%         1.000000      0.340000      0.333300      0.480000      0.104500
# 50%         1.000000      0.500000      0.484800      0.630000      0.194000
# 75%         2.000000      0.660000      0.621200      0.780000      0.253700
# max         4.000000      1.000000      1.000000      1.000000      0.850700
#
#               casual    registered           cnt
# count   17379.000000  17379.000000  17379.000000
# unique           NaN           NaN           NaN
# top              NaN           NaN           NaN
# freq             NaN           NaN           NaN
# first            NaN           NaN           NaN
# last             NaN           NaN           NaN
# mean       35.676218    153.786869    189.463088
# std        49.305030    151.357286    181.387599
# min         0.000000      0.000000      1.000000
# 25%         4.000000     34.000000     40.000000
# 50%        17.000000    115.000000    142.000000
# 75%        48.000000    220.000000    281.000000
# max       367.000000    886.000000    977.000000

# %%
#melihat korelasi antar variabel yang ingin di eksplor
hour_df.corr()
# Out:
# <ipython-input-21-c4fa615a1e0b>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   hour_df.corr()
#              instant    season        yr      mnth        hr   holiday  \
# instant     1.000000  0.404046  0.866014  0.489164 -0.004775  0.014723
# season      0.404046  1.000000 -0.010742  0.830386 -0.006117 -0.009585
# yr          0.866014 -0.010742  1.000000 -0.010473 -0.003867  0.006692
# mnth        0.489164  0.830386 -0.010473  1.000000 -0.005772  0.018430
# hr         -0.004775 -0.006117 -0.003867 -0.005772  1.000000  0.000479
# holiday     0.014723 -0.009585  0.006692  0.018430  0.000479  1.000000
# weekday     0.001357 -0.002335 -0.004485  0.010400 -0.003498 -0.102088
# workingday -0.003416  0.013743 -0.002196 -0.003477  0.002285 -0.252471
# weathersit -0.014198 -0.014524 -0.019157  0.005400 -0.020203 -0.017036
# temp        0.136178  0.312025  0.040913  0.201691  0.137603 -0.027340
# atemp       0.137615  0.319380  0.039222  0.208096  0.133750 -0.030973
# hum         0.009577  0.150625 -0.083546  0.164411 -0.276498 -0.010588
# windspeed  -0.074505 -0.149773 -0.008740 -0.135386  0.137252  0.003988
# casual      0.158295  0.120206  0.142779  0.068457  0.301202  0.031564
# registered  0.282046  0.174226  0.253684  0.122273  0.374141 -0.047345
# cnt         0.278379  0.178056  0.250495  0.120638  0.394071 -0.030927
#
#              weekday  workingday  weathersit      temp     atemp       hum  \
# instant     0.001357   -0.003416   -0.014198  0.136178  0.137615  0.009577
# season     -0.002335    0.013743   -0.014524  0.312025  0.319380  0.150625
# yr         -0.004485   -0.002196   -0.019157  0.040913  0.039222 -0.083546
# mnth        0.010400   -0.003477    0.005400  0.201691  0.208096  0.164411
# hr         -0.003498    0.002285   -0.020203  0.137603  0.133750 -0.276498
# holiday    -0.102088   -0.252471   -0.017036 -0.027340 -0.030973 -0.010588
# weekday     1.000000    0.035955    0.003311 -0.001795 -0.008821 -0.037158
# workingday  0.035955    1.000000    0.044672  0.055390  0.054667  0.015688
# weathersit  0.003311    0.044672    1.000000 -0.102640 -0.105563  0.418130
# temp       -0.001795    0.055390   -0.102640  1.000000  0.987672 -0.069881
# atemp      -0.008821    0.054667   -0.105563  0.987672  1.000000 -0.051918
# hum        -0.037158    0.015688    0.418130 -0.069881 -0.051918  1.000000
# windspeed   0.011502   -0.011830    0.026226 -0.023125 -0.062336 -0.290105
# casual      0.032721   -0.300942   -0.152628  0.459616  0.454080 -0.347028
# registered  0.021578    0.134326   -0.120966  0.335361  0.332559 -0.273933
# cnt         0.026900    0.030284   -0.142426  0.404772  0.400929 -0.322911
#
#             windspeed    casual  registered       cnt
# instant     -0.074505  0.158295    0.282046  0.278379
# season      -0.149773  0.120206    0.174226  0.178056
# yr          -0.008740  0.142779    0.253684  0.250495
# mnth        -0.135386  0.068457    0.122273  0.120638
# hr           0.137252  0.301202    0.374141  0.394071
# holiday      0.003988  0.031564   -0.047345 -0.030927
# weekday      0.011502  0.032721    0.021578  0.026900
# workingday  -0.011830 -0.300942    0.134326  0.030284
# weathersit   0.026226 -0.152628   -0.120966 -0.142426
# temp        -0.023125  0.459616    0.335361  0.404772
# atemp       -0.062336  0.454080    0.332559  0.400929
# hum         -0.290105 -0.347028   -0.273933 -0.322911
# windspeed    1.000000  0.090287    0.082321  0.093234
# casual       0.090287  1.000000    0.506618  0.694564
# registered   0.082321  0.506618    1.000000  0.972151
# cnt          0.093234  0.694564    0.972151  1.000000

# %%
#tampilan heatmap dari korelasi antar variabel yang memungkinkan
variable_df = hour_df[['season','yr','mnth','weekday','weathersit','temp','hum','windspeed','casual','registered','cnt']]

fig, axes = plt.subplots(1, 4, figsize=(15, 6))

# iterasi untuk setiap season yang ada (spring, summer, autumn, winter)
for i, season_value in enumerate(variable_df["season"].unique()):
    season_name =  season_value

    # filter data untuk season sekarang
    season_data = variable_df[variable_df["season"] == season_value]

    # plot heatmap untuk setiap season
    corr_matrix = season_data.corr(numeric_only=True, method='spearman')
    sns.heatmap(corr_matrix, annot=True, cmap="coolwarm", vmin=-1, vmax=1, ax=axes[i])
    axes[i].set_title(f"Season: {season_name}")

plt.subplots_adjust(left=1, right=3, top=0.9, bottom=0.1)

plt.show()

# %% [markdown]
# berikut ini adalah beberapa variabel yang saling berkorelasi berdasarkan pengecekan di atas<br>
# - humidity - weathersit <br>
# - cnt - temp <br>
# - cnt - month <br>
# - weekday - cnt <br>
# - dsb. <br>
#
# hal ini menunjukkan variabel2 yang diperlukan oleh pertanyaan2 sebelumnya
# ternyata bisa dianalisis karena memiliki korelasi satu sama lain

# %%
#untuk melihat perbandingan pengguna sepeda tiap jam di tiap harinya
hour_df.groupby(by="weekday").agg({
    'casual': 'mean',
    'registered': 'mean',
    'cnt': ['mean', 'max', 'min']
})
# Out:
#             casual  registered         cnt
#               mean        mean        mean  max min
# weekday
# 0        56.163469  121.305356  177.468825  776   1
# 1        28.553449  155.191206  183.744655  968   1
# 2        23.580514  167.658377  191.238891  970   1
# 3        23.159192  167.971313  191.130505  977   1
# 4        24.872521  171.564144  196.436665  976   1
# 5        31.458786  164.677121  196.135907  957   1
# 6        61.246815  128.962978  190.209793  783   1

# %%
#pengaruh temperatur udara terhadap pengguna sepeda di setiap jam nya
hour_df.groupby(by="temp").agg({
    'casual': 'mean',
    'registered': 'mean',
    'cnt': 'mean'
})
# Out:
#           casual  registered         cnt
# temp
# 0.02    0.941176   40.941176   41.882353
# 0.04    1.750000   33.875000   35.625000
# 0.06    2.750000   39.250000   42.000000
# 0.08    1.941176   26.294118   28.235294
# 0.10    1.666667   47.627451   49.294118
# 0.12    2.223684   56.197368   58.421053
# 0.14    2.434783   52.673913   55.108696
# 0.16    3.486957   62.091304   65.578261
# 0.18    3.309677   56.806452   60.116129
# 0.20    4.073446   75.672316   79.745763
# 0.22    4.508314   65.406176   69.914489
# 0.24    5.745211   74.413793   80.159004
# 0.26    7.828265   80.132379   87.960644
# 0.28   10.305648   96.445183  106.750831
# 0.30   11.121685  104.795632  115.917317
# 0.32   13.693944  120.536825  134.230769
# 0.34   15.097674  120.210853  135.308527
# 0.36   19.032787  128.809240  147.842027
# 0.38   21.239247  142.973118  164.212366
# 0.40   25.022801  142.418567  167.441368
# 0.42   26.673358  148.667883  175.341241
# 0.44   25.548323  133.358974  158.907298
# 0.46   28.953488  133.953488  162.906977
# 0.48   37.802083  152.631944  190.434028
# 0.50   40.305085  158.124294  198.429379
# 0.52   37.924460  165.043165  202.967626
# 0.54   37.318102  162.966608  200.284710
# 0.56   41.300518  172.440415  213.740933
# 0.58   41.518033  180.547541  222.065574
# 0.60   43.617778  178.463704  222.081481
# 0.62   40.783747  163.327824  204.111570
# 0.64   47.338150  176.628613  223.966763
# 0.66   47.310245  178.092352  225.402597
# 0.68   47.524355  162.014327  209.538682
# 0.70   53.749275  203.204348  256.953623
# 0.72   68.696491  218.056140  286.752632
# 0.74   74.405039  238.748062  313.153101
# 0.76   82.512626  260.063131  342.575758
# 0.78   76.130178  237.065089  313.195266
# 0.80   85.292308  262.083077  347.375385
# 0.82   88.276995  251.413146  339.690141
# 0.84   83.456522  242.362319  325.818841
# 0.86   80.580153  242.374046  322.954198
# 0.88   97.962264  265.698113  363.660377
# 0.90   75.600000  233.688889  309.288889
# 0.92   76.448980  243.571429  320.020408
# 0.94   60.000000  157.058824  217.058824
# 0.96   66.437500  208.062500  274.500000
# 0.98   82.000000  457.000000  539.000000
# 1.00  102.000000  192.000000  294.000000

# %%
# Menghitung rata-rata jumlah pengguna sepeda berdasarkan suhu (pertanyaan nomor 1)
warnings.simplefilter(action='ignore', category=FutureWarning)

#membuat dataframe baru
temperature_df = hour_df.groupby(pd.cut(hour_df['temp'], bins=10)).agg({
    'casual': 'mean',
    'registered': 'mean',
    'cnt': 'mean'
}).reset_index()

temperature_df
# Out:
#              temp     casual  registered         cnt
# 0  (0.019, 0.118]   1.760684   40.529915   42.290598
# 1  (0.118, 0.216]   3.422875   64.442812   67.865687
# 2  (0.216, 0.314]   7.980360   84.851882   92.832242
# 3  (0.314, 0.412]  18.585994  129.847580  148.433574
# 4   (0.412, 0.51]  31.255240  144.630086  175.885327
# 5   (0.51, 0.608]  40.364382  171.335693  211.700075
# 6  (0.608, 0.706]  47.246349  178.087302  225.333651
# 7  (0.706, 0.804]  76.321356  240.744939  317.066296
# 8  (0.804, 0.902]  84.595200  246.179200  330.774400
# 9    (0.902, 1.0]  71.583333  221.226190  292.809524

# %%
#mengetes kemungkinan jawaban pertanyaan nomor 2
monthly_users_df = hour_df.groupby(['yr', 'mnth']).agg({
    'casual': 'sum',
    'registered': 'sum'
}).reset_index()

#untuk tahun 2011
monthly_users_df[monthly_users_df['yr'] == 0]
# Out:
#     yr  mnth  casual  registered
# 12   1     1    8969       87775
# 13   1     2    8721       94416
# 14   1     3   31618      133257
# 15   1     4   38456      135768
# 16   1     5   44235      151630
# 17   1     6   43294      159536
# 18   1     7   41705      161902
# 19   1     8   43197      171306
# 20   1     9   43778      174795
# 21   1    10   34538      164303
# 22   1    11   21009      131655
# 23   1    12   13245      110468

# %%
#untuk tahun 2012
monthly_users_df[monthly_users_df['yr'] == 1]
# Out:
#     yr  mnth  casual  registered
# 12   1     1    8969       87775
# 13   1     2    8721       94416
# 14   1     3   31618      133257
# 15   1     4   38456      135768
# 16   1     5   44235      151630
# 17   1     6   43294      159536
# 18   1     7   41705      161902
# 19   1     8   43197      171306
# 20   1     9   43778      174795
# 21   1    10   34538      164303
# 22   1    11   21009      131655
# 23   1    12   13245      110468

# %%
# Menghitung total pengguna sepeda (casual dan terdaftar) untuk setiap hari dalam seminggu. mengetes kemungkinan pertanyaan nomor 3
daily_users_df = hour_df.groupby(['yr', 'weekday']).agg({
    'casual': 'sum',
    'registered': 'sum',
    'cnt': 'sum'
}).reset_index()

#daily user tiap jam di tiap hari nya pada tahun 2011
daily_users_df[daily_users_df['yr']==0]
# Out:
#    yr  weekday  casual  registered     cnt
# 0   0        0   59603      117471  177074
# 1   0        1   31560      148661  180221
# 2   0        2   23989      156349  180338
# 3   0        3   20660      148509  169169
# 4   0        4   22440      152112  174552
# 5   0        5   29453      152553  182006
# 6   0        6   59547      120196  179743

# %%
#daily user tiap jam pada tahun 2012
daily_users_df[daily_users_df['yr']==1]
# Out:
#     yr  weekday  casual  registered     cnt
# 7    1        0   80918      186035  266953
# 8    1        1   39224      236058  275282
# 9    1        2   33854      254917  288771
# 10   1        3   36659      267220  303879
# 11   1        4   39020      271823  310843
# 12   1        5   48785      256999  305784
# 13   1        6   94305      203759  298064

# %% [markdown]
# ### B. Explore day_df

# %%
#mengecek semua kolom menggunakan include all
day_df.describe(include="all")
# Out:
#            instant               dteday      season          yr        mnth  \
# count   731.000000                  731  731.000000  731.000000  731.000000
# unique         NaN                  731         NaN         NaN         NaN
# top            NaN  2011-01-01 00:00:00         NaN         NaN         NaN
# freq           NaN                    1         NaN         NaN         NaN
# first          NaN  2011-01-01 00:00:00         NaN         NaN         NaN
# last           NaN  2012-12-31 00:00:00         NaN         NaN         NaN
# mean    366.000000                  NaN    2.496580    0.500684    6.519836
# std     211.165812                  NaN    1.110807    0.500342    3.451913
# min       1.000000                  NaN    1.000000    0.000000    1.000000
# 25%     183.500000                  NaN    2.000000    0.000000    4.000000
# 50%     366.000000                  NaN    3.000000    1.000000    7.000000
# 75%     548.500000                  NaN    3.000000    1.000000   10.000000
# max     731.000000                  NaN    4.000000    1.000000   12.000000
#
#            holiday     weekday  workingday  weathersit        temp  \
# count   731.000000  731.000000  731.000000  731.000000  731.000000
# unique         NaN         NaN         NaN         NaN         NaN
# top            NaN         NaN         NaN         NaN         NaN
# freq           NaN         NaN         NaN         NaN         NaN
# first          NaN         NaN         NaN         NaN         NaN
# last           NaN         NaN         NaN         NaN         NaN
# mean      0.028728    2.997264    0.683995    1.395349    0.495385
# std       0.167155    2.004787    0.465233    0.544894    0.183051
# min       0.000000    0.000000    0.000000    1.000000    0.059130
# 25%       0.000000    1.000000    0.000000    1.000000    0.337083
# 50%       0.000000    3.000000    1.000000    1.000000    0.498333
# 75%       0.000000    5.000000    1.000000    2.000000    0.655417
# max       1.000000    6.000000    1.000000    3.000000    0.861667
#
#              atemp         hum   windspeed       casual   registered  \
# count   731.000000  731.000000  731.000000   731.000000   731.000000
# unique         NaN         NaN         NaN          NaN          NaN
# top            NaN         NaN         NaN          NaN          NaN
# freq           NaN         NaN         NaN          NaN          NaN
# first          NaN         NaN         NaN          NaN          NaN
# last           NaN         NaN         NaN          NaN          NaN
# mean      0.474354    0.627894    0.190486   848.176471  3656.172367
# std       0.162961    0.142429    0.077498   686.622488  1560.256377
# min       0.079070    0.000000    0.022392     2.000000    20.000000
# 25%       0.337842    0.520000    0.134950   315.500000  2497.000000
# 50%       0.486733    0.626667    0.180975   713.000000  3662.000000
# 75%       0.608602    0.730209    0.233214  1096.000000  4776.500000
# max       0.840896    0.972500    0.507463  3410.000000  6946.000000
#
#                 cnt
# count    731.000000
# unique          NaN
# top             NaN
# freq            NaN
# first           NaN
# last            NaN
# mean    4504.348837
# std     1937.211452
# min       22.000000
# 25%     3152.000000
# 50%     4548.000000
# 75%     5956.000000
# max     8714.000000

# %%
#melihat korelasi antar variabel yang ingin di eksplor
day_df.corr()
# Out:
#              instant    season        yr      mnth   holiday   weekday  \
# instant     1.000000  0.412224  0.866025  0.496702  0.016145 -0.000016
# season      0.412224  1.000000 -0.001844  0.831440 -0.010537 -0.003080
# yr          0.866025 -0.001844  1.000000 -0.001792  0.007954 -0.005461
# mnth        0.496702  0.831440 -0.001792  1.000000  0.019191  0.009509
# holiday     0.016145 -0.010537  0.007954  0.019191  1.000000 -0.101960
# weekday    -0.000016 -0.003080 -0.005461  0.009509 -0.101960  1.000000
# workingday -0.004337  0.012485 -0.002013 -0.005901 -0.253023  0.035790
# weathersit -0.021477  0.019211 -0.048727  0.043528 -0.034627  0.031087
# temp        0.150580  0.334315  0.047604  0.220205 -0.028556 -0.000170
# atemp       0.152638  0.342876  0.046106  0.227459 -0.032507 -0.007537
# hum         0.016375  0.205445 -0.110651  0.222204 -0.015937 -0.052232
# windspeed  -0.112620 -0.229046 -0.011817 -0.207502  0.006292  0.014282
# casual      0.275255  0.210399  0.248546  0.123006  0.054274  0.059923
# registered  0.659623  0.411623  0.594248  0.293488 -0.108745  0.057367
# cnt         0.628830  0.406100  0.566710  0.279977 -0.068348  0.067443
#
#             workingday  weathersit      temp     atemp       hum  windspeed  \
# instant      -0.004337   -0.021477  0.150580  0.152638  0.016375  -0.112620
# season        0.012485    0.019211  0.334315  0.342876  0.205445  -0.229046
# yr           -0.002013   -0.048727  0.047604  0.046106 -0.110651  -0.011817
# mnth         -0.005901    0.043528  0.220205  0.227459  0.222204  -0.207502
# holiday      -0.253023   -0.034627 -0.028556 -0.032507 -0.015937   0.006292
# weekday       0.035790    0.031087 -0.000170 -0.007537 -0.052232   0.014282
# workingday    1.000000    0.061200  0.052660  0.052182  0.024327  -0.018796
# weathersit    0.061200    1.000000 -0.120602 -0.121583  0.591045   0.039511
# temp          0.052660   -0.120602  1.000000  0.991702  0.126963  -0.157944
# atemp         0.052182   -0.121583  0.991702  1.000000  0.139988  -0.183643
# hum           0.024327    0.591045  0.126963  0.139988  1.000000  -0.248489
# windspeed    -0.018796    0.039511 -0.157944 -0.183643 -0.248489   1.000000
# casual       -0.518044   -0.247353  0.543285  0.543864 -0.077008  -0.167613
# registered    0.303907   -0.260388  0.540012  0.544192 -0.091089  -0.217449
# cnt           0.061156   -0.297391  0.627494  0.631066 -0.100659  -0.234545
#
#               casual  registered       cnt
# instant     0.275255    0.659623  0.628830
# season      0.210399    0.411623  0.406100
# yr          0.248546    0.594248  0.566710
# mnth        0.123006    0.293488  0.279977
# holiday     0.054274   -0.108745 -0.068348
# weekday     0.059923    0.057367  0.067443
# workingday -0.518044    0.303907  0.061156
# weathersit -0.247353   -0.260388 -0.297391
# temp        0.543285    0.540012  0.627494
# atemp       0.543864    0.544192  0.631066
# hum        -0.077008   -0.091089 -0.100659
# windspeed  -0.167613   -0.217449 -0.234545
# casual      1.000000    0.395282  0.672804
# registered  0.395282    1.000000  0.945517
# cnt         0.672804    0.945517  1.000000

# %%
#tampilan heatmap dari korelasi antar variabel
variable_df = day_df[['season','yr','mnth','weekday','weathersit','temp','hum','windspeed','casual','registered','cnt']]

fig, axes = plt.subplots(1, 4, figsize=(15, 6))

# iterasi untuk setiap season yang ada (spring, summer, autumn, winter)
for i, season_value in enumerate(variable_df["season"].unique()):
    season_name =  season_value

    # filter data untuk season sekarang
    season_data = variable_df[variable_df["season"] == season_value]

    # plot heatmap untuk setiap season
    corr_matrix = season_data.corr(numeric_only=True, method='spearman')
    sns.heatmap(corr_matrix, annot=True, cmap="coolwarm", vmin=-1, vmax=1, ax=axes[i])
    axes[i].set_title(f"Season: {season_name}")

plt.subplots_adjust(left=1, right=3, top=0.9, bottom=0.1)

plt.show()

# %%
#mengetes kemungkinan jawaban pertanyaan nomor 2 dari sudut pandang perharinya
monthly_users_df = hour_df.groupby(['yr', 'mnth']).agg({
    'casual': 'sum',
    'registered': 'sum'
}).reset_index()

#untuk tahun 2011
monthly_users_df[monthly_users_df['yr'] == 0]
# Out:
#     yr  mnth  casual  registered
# 0    0     1    3073       35116
# 1    0     2    6242       41973
# 2    0     3   12826       51219
# 3    0     4   22346       72524
# 4    0     5   31050      104771
# 5    0     6   30612      112900
# 6    0     7   36452      104889
# 7    0     8   28842      107849
# 8    0     9   26545      100873
# 9    0    10   25222       98289
# 10   0    11   15594       86573
# 11   0    12    8448       78875

# %%
#untuk tahun 2012
monthly_users_df[monthly_users_df['yr'] == 1]
# Out:
#     yr  mnth  casual  registered
# 12   1     1    8969       87775
# 13   1     2    8721       94416
# 14   1     3   31618      133257
# 15   1     4   38456      135768
# 16   1     5   44235      151630
# 17   1     6   43294      159536
# 18   1     7   41705      161902
# 19   1     8   43197      171306
# 20   1     9   43778      174795
# 21   1    10   34538      164303
# 22   1    11   21009      131655
# 23   1    12   13245      110468

# %%
# Menghitung total pengguna sepeda (casual dan terdaftar) untuk setiap hari dalam seminggu. mengetes kemungkinan pertanyaan nomor 3 dari sudut pandang perharinya
daily_users_df = hour_df.groupby(['yr', 'weekday']).agg({
    'casual': 'sum',
    'registered': 'sum',
    'cnt': 'sum'
}).reset_index()

#daily user di tiap hari nya pada tahun 2011
daily_users_df[daily_users_df['yr']==0]
# Out:
#    yr  weekday  casual  registered     cnt
# 0   0        0   59603      117471  177074
# 1   0        1   31560      148661  180221
# 2   0        2   23989      156349  180338
# 3   0        3   20660      148509  169169
# 4   0        4   22440      152112  174552
# 5   0        5   29453      152553  182006
# 6   0        6   59547      120196  179743

# %%
#daily user di tiap hari nya pada tahun 2012
daily_users_df[daily_users_df['yr']==1]
# Out:
#     yr  weekday  casual  registered     cnt
# 7    1        0   80918      186035  266953
# 8    1        1   39224      236058  275282
# 9    1        2   33854      254917  288771
# 10   1        3   36659      267220  303879
# 11   1        4   39020      271823  310843
# 12   1        5   48785      256999  305784
# 13   1        6   94305      203759  298064

# %% [markdown]
# ## Visualization & Explanatory Analysis

# %%
#formatting hour_df untuk keperluan visualisasi selanjutnya
#mengubah format season menjadi string
season_mapping = {1: 'Spring', 2: 'Summer', 3: 'Autumn', 4: 'Winter'}
hour_df['season'] = hour_df['season'].replace(season_mapping)\

#mengubah format yr menjadi string
yr_mapping = {0: '2011', 1: '2012'}
hour_df['yr'] = hour_df['yr'].replace(yr_mapping)

#mengubah format weekday menjadi string
day_mapping = {0: 'Sunday', 1: 'Monday', 2: 'Tuesday', 3: 'Wednesday', 4: 'Thursday', 5: 'Friday', 6: 'Saturday'}
hour_df['weekday'] = hour_df['weekday'].replace(day_mapping)

hour_df.sample(10)
# Out:
#        instant     dteday  season    yr  mnth  hr  holiday   weekday  \
# 12723    12724 2012-06-19  Summer  2012     6   8        0   Tuesday
# 10987    10988 2012-04-07  Summer  2012     4  23        0  Saturday
# 2412      2413 2011-04-15  Summer  2011     4  10        1    Friday
# 8806      8807 2012-01-07  Spring  2012     1  18        0  Saturday
# 14680    14681 2012-09-08  Autumn  2012     9  21        0  Saturday
# 1576      1577 2011-03-11  Spring  2011     3   3        0    Friday
# 6485      6486 2011-10-02  Winter  2011    10  19        0    Sunday
# 10107    10108 2012-03-02  Spring  2012     3   5        0    Friday
# 3924      3925 2011-06-17  Summer  2011     6  10        0    Friday
# 11976    11977 2012-05-19  Summer  2012     5   5        0  Saturday
#
#        workingday  weathersit  temp   atemp   hum  windspeed  casual  \
# 12723           1           2  0.60  0.5758  0.78     0.1642      40
# 10987           0           1  0.46  0.4545  0.23     0.2239      32
# 2412            0           1  0.50  0.4848  0.55     0.1940      31
# 8806            0           1  0.54  0.5152  0.45     0.1343      49
# 14680           0           2  0.60  0.5606  0.83     0.1642      26
# 1576            1           2  0.32  0.3333  0.93     0.0896       0
# 6485            0           2  0.38  0.3939  0.76     0.1642      34
# 10107           1           1  0.30  0.3333  0.70     0.0000       0
# 3924            1           1  0.70  0.6515  0.58     0.1940      44
# 11976           0           1  0.46  0.4545  0.67     0.0000       1
#
#        registered  cnt
# 12723         633  673
# 10987          86  118
# 2412           91  122
# 8806          248  297
# 14680         155  181
# 1576            2    2
# 6485          128  162
# 10107          24   24
# 3924          126  170
# 11976          11   12

# %%
#formatting day_df untuk keperluan visualisasi selanjutnya juga
#mengubah format season menjadi string
season_mapping = {1: 'Spring', 2: 'Summer', 3: 'Autumn', 4: 'Winter'}
day_df['season'] = day_df['season'].replace(season_mapping)

#mengubah format yr menjadi string
yr_mapping = {0: '2011', 1: '2012'}
day_df['yr'] = day_df['yr'].replace(yr_mapping)

#mengubah format weekday menjadi string
day_mapping = {0: 'Sunday', 1: 'Monday', 2: 'Tuesday', 3: 'Wednesday', 4: 'Thursday', 5: 'Friday', 6: 'Saturday'}
day_df['weekday'] = day_df['weekday'].replace(day_mapping)

day_df.sample(10)
# Out:
#      instant     dteday  season    yr  mnth  holiday    weekday  workingday  \
# 107      108 2011-04-18  Summer  2011     4        0     Monday           1
# 601      602 2012-08-24  Autumn  2012     8        0     Friday           1
# 172      173 2011-06-22  Autumn  2011     6        0  Wednesday           1
# 451      452 2012-03-27  Summer  2012     3        0    Tuesday           1
# 395      396 2012-01-31  Spring  2012     1        0    Tuesday           1
# 637      638 2012-09-29  Winter  2012     9        0   Saturday           0
# 322      323 2011-11-19  Winter  2011    11        0   Saturday           0
# 161      162 2011-06-11  Summer  2011     6        0   Saturday           0
# 688      689 2012-11-19  Winter  2012    11        0     Monday           1
# 88        89 2011-03-30  Summer  2011     3        0  Wednesday           1
#
#      weathersit      temp     atemp       hum  windspeed  casual  registered  \
# 107           1  0.512500  0.503146  0.542500   0.163567     669        2760
# 601           2  0.702500  0.647100  0.615000   0.072146    1325        6257
# 172           1  0.733333  0.693829  0.707500   0.172262     661        3846
# 451           1  0.323333  0.315654  0.290000   0.187192     531        4571
# 395           1  0.390000  0.381317  0.416667   0.261817     324        4185
# 637           1  0.542500  0.530296  0.542917   0.227604    2589        5966
# 322           1  0.329167  0.324483  0.502083   0.224496     943        2720
# 161           1  0.725000  0.678038  0.654583   0.154850    1729        3237
# 688           2  0.380833  0.375621  0.623333   0.235067     449        5050
# 88            2  0.300000  0.297350  0.646667   0.172888     168        1368
#
#       cnt
# 107  3429
# 601  7582
# 172  4507
# 451  5102
# 395  4509
# 637  8555
# 322  3663
# 161  4966
# 688  5499
# 88   1536

# %% [markdown]
# ### Pertanyaan 1: Bagaimana pengaruh temperatur udara terhadap penggunaan sepeda?

# %%
# Buat bar chart untuk cnt - temp
plt.figure(figsize=(10, 6))
sns.barplot(x='temp', y='cnt', data=temperature_df, color='skyblue', label='Total rider')

# Tambahkan judul dan label sumbu
plt.title('Pengaruh Suhu Terhadap Penggunaan Sepeda')
plt.xlabel('Rentang Suhu (°C)')
plt.ylabel('Rata-rata Pengguna')
plt.xticks(rotation=45)

# Tampilkan legenda
plt.legend()

# Tampilkan chart
plt.show()

# %% [markdown]
# ### Pertanyaan 2: Bagaimana perkembangan casual dan registered user selama 2 tahun ini?

# %%
#menjadikan dteday sebagai indeks
day_df.set_index('dteday', inplace=True)

# %%
# Plot data
plt.figure(figsize=(30, 8))
plt.plot(day_df['casual'], label='Casual Users')
plt.plot(day_df['registered'], label='Registered Users')

# Judul dan label
plt.title('Casual vs Registered Users (2011-1-1 to 2012-12-31)')
plt.xlabel('Month')
plt.ylabel('Number of Users')

# Tampilkan legenda
plt.legend()

# Tampilkan plot
plt.show()

# %% [markdown]
# ### Pertanyaan 3: Bagaimana perbedaan penggunaan sepeda di tiap harinya untuk setiap tahun? (Hari apa yang paling laris?)

# %%
# Buat DataFrame baru yang mengelompokkan data berdasarkan 'weekday' dan 'yr', dan menghitung total 'cnt'
grouped = day_df.groupby(['weekday', 'yr'])['cnt'].sum().reset_index()

# Urutkan DataFrame berdasarkan 'cnt' secara descending
grouped.sort_values('cnt', ascending=False, inplace=True)

# Buat pivot table dari DataFrame yang dikelompokkan
pivot = grouped.pivot(index='weekday', columns='yr', values='cnt')

# Buat plot dengan ukuran figure yang diinginkan
ax = pivot.plot(kind='bar', stacked=False, figsize=(15, 6), width=0.9)

# Atur judul dan label sumbu
plt.title('Hari apa yang paling laris?')
plt.xlabel('Hari')
plt.ylabel('Banyaknya Pengguna')
plt.xticks(rotation=15)

# Tambahkan nilai di atas masing-masing bar
for p in ax.patches:
    ax.annotate(str(p.get_height()), (p.get_x() * 1.005, p.get_height() * 1.005))

# Tampilkan plot
plt.show()

# %% [markdown]
# ## Conclusion

# %% [markdown]
# - Conclusion pertanyaan 1 : Pengguna lebih menyukai penggunaan sepeda ketika suhu semakin hangat
# - Conclusion pertanyaan 2: Terdapat peningkatan pengguna (registered) yang signifikan dari tahun 2011 ke tahun 2012, hal ini menunjukkan sistem bike sharing ini cukup efektif
# - Conclusion pertanyaan 3: Untuk tahun 2011 pengguna paling banyak adalah ketika hari selasa sedangkan pada tahun 2012 adalah hari kamis, hal ini sangat didominasi oleh beberapa faktor seperti hari libur dan cuaca setiap tahun

# %% [markdown]
# Adapun beberapa poin menarik yang bisa dilihat dari hasil analisis ini:
# - Berdasarkan data, cuaca dan hari libur atau akhir pekan berpengaruh pada jumlah pengguna sistem bike sharing.
# - Suhu tinggi meningkatkan jumlah pengguna, sedangkan kelembaban tinggi menurunkannya.
# - Di hari kerja, perjalanan santai lebih sedikit karena banyak pengguna yang berangkat kerja, menciptakan dua puncak kepadatan pengguna.
# - Di hari libur, pola pengguna berbeda yakni hanya satu puncak kepadatan pengguna.

# %%
# ambil dataframe yang dibutuhkan untuk dashboard
#no1
temperature_df.to_csv("temperature.csv", index=False)
#no2
day_df.to_csv("dayy.csv", index=False)
#no3
grouped.to_csv("grouped.csv", index=False)
